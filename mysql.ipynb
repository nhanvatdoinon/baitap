# %%
import mysql.connector
import requests
import csv

# %%
conn = mysql.connector.connect(
      host ="localhost",
      user ="root",
      passwd ="kimtoan123",
      database = "QlSinhVien1"
)

# %%
cursor = conn.cursor()

# %%
customer = '''create table customers(
    Ten varchar(255),
    DiaChi varchar(255),
    SoDienThoai varchar(10)
);'''

# %%
cursor.execute(customer)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     522                 query = query.encode('utf-8')
# --> 523             self._cmysql.query(query,
#     524                                raw=raw, buffered=buffered,
#
# MySQLInterfaceError: Table 'customers' already exists
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-40-14d5eaf262c8> in <module>
# ----> 1 cursor.execute(customer)
#
# ~\anaconda3\lib\site-packages\mysql\connector\cursor_cext.py in execute(self, operation, params, multi)
#     267
#     268         try:
# --> 269             result = self._cnx.cmd_query(stmt, raw=self._raw,
#     270                                          buffered=self._buffered,
#     271                                          raw_as_string=self._raw_as_string)
#
# ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     526                                query_attrs=self._query_attrs)
#     527         except MySQLInterfaceError as exc:
# --> 528             raise errors.get_mysql_exception(exc.errno, msg=exc.msg,
#     529                                              sqlstate=exc.sqlstate)
#     530         except AttributeError:
#
# ProgrammingError: 1050 (42S01): Table 'customers' already exists

# %%
response_get_customer = requests.get("https://007af9e4efaee0e02d3101cce3eb07b3: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@luxury-4832.myshopify.com/admin/api/2022-10/customers.json?limit=100")

# %%
response_get_customer.text
# Out:
# '{"customers":[{"id":6697587245364,"email":"kimtoan221221@example.com","accepts_marketing":false,"created_at":"2022-11-24T14:59:23+07:00","updated_at":"2022-11-24T14:59:23+07:00","first_name":"Toànn","last_name":"Kim","orders_count":0,"state":"disabled","total_spent":"0.00","last_order_id":null,"note":null,"verified_email":true,"multipass_identifier":null,"tax_exempt":false,"tags":"","last_order_name":null,"currency":"USD","phone":"+84888666331","addresses":[{"id":8959869878580,"customer_id":6697587245364,"first_name":"Toàn","last_name":"Nguyễn","company":null,"address1":"HN","address2":null,"city":"HN","province":"ON","country":"Vietnam","zip":"123ABC","phone":"+84 999322138","name":"Toàn Nguyễn","province_code":null,"country_code":"VN","country_name":"Vietnam","default":true}],"accepts_marketing_updated_at":"2022-11-24T14:59:23+07:00","marketing_opt_in_level":null,"tax_exemptions":[],"email_marketing_consent":{"state":"not_subscribed","opt_in_level":"single_opt_in","consent_updated_at":null},"sms_marketing_consent":{"state":"not_subscribed","opt_in_level":"single_opt_in","consent_updated_at":null,"consent_collected_from":"OTHER"},"admin_graphql_api_id":"gid:\\/\\/shopify\\/Customer\\/6697587245364","default_address":{"id":8959869878580,"customer_id":6697587245364,"first_name":"Toàn","last_name":"Nguyễn","company":null,"address1":"HN","address2":null,"city":"HN","province":"ON","country":"Vietnam","zip":"123ABC","phone":"+84 999322138","name":"Toàn Nguyễn","province_code":null,"country_code":"VN","country_name":"Vietnam","default":true}},{"id":6697346629940,"email":"kimtoan22122@example.com","accepts_marketing":false,"created_at":"2022-11-24T08:05:12+07:00","updated_at":"2022-11-24T14:42:50+07:00","first_name":"Toànn","last_name":"Kim","orders_count":6,"state":"disabled","total_spent":"480.00","last_order_id":5210766967092,"note":null,"verified_email":true,"multipass_identifier":null,"tax_exempt":false,"tags":"","last_order_name":"LX1006VN","currency":"USD","phone":"+84888666336","addresses":[{"id":8959278776628,"customer_id":6697346629940,"first_name":"Toàn","last_name":"Nguyễn","company":null,"address1":"HN","address2":null,"city":"HN","province":"ON","country":"Vietnam","zip":"123ABC","phone":"+84 999322338","name":"Toàn Nguyễn","province_code":null,"country_code":"VN","country_name":"Vietnam","default":true}],"accepts_marketing_updated_at":"2022-11-24T08:05:12+07:00","marketing_opt_in_level":null,"tax_exemptions":[],"email_marketing_consent":{"state":"not_subscribed","opt_in_level":"single_opt_in","consent_updated_at":null},"sms_marketing_consent":{"state":"not_subscribed","opt_in_level":"single_opt_in","consent_updated_at":null,"consent_collected_from":"OTHER"},"admin_graphql_api_id":"gid:\\/\\/shopify\\/Customer\\/6697346629940","default_address":{"id":8959278776628,"customer_id":6697346629940,"first_name":"Toàn","last_name":"Nguyễn","company":null,"address1":"HN","address2":null,"city":"HN","province":"ON","country":"Vietnam","zip":"123ABC","phone":"+84 999322338","name":"Toàn Nguyễn","province_code":null,"country_code":"VN","country_name":"Vietnam","default":true}},{"id":6697343648052,"email":"kimtoan2212@example.com","accepts_marketing":false,"created_at":"2022-11-24T07:59:18+07:00","updated_at":"2022-11-24T07:59:18+07:00","first_name":"Toànn","last_name":"Kim","orders_count":0,"state":"disabled","total_spent":"0.00","last_order_id":null,"note":null,"verified_email":true,"multipass_identifier":null,"tax_exempt":false,"tags":"","last_order_name":null,"currency":"USD","phone":"+84888666332","addresses":[],"accepts_marketing_updated_at":"2022-11-24T07:59:18+07:00","marketing_opt_in_level":null,"tax_exemptions":[],"email_marketing_consent":{"state":"not_subscribed","opt_in_level":"single_opt_in","consent_updated_at":null},"sms_marketing_consent":{"state":"not_subscribed","opt_in_level":"single_opt_in","consent_updated_at":null,"consent_collected_from":"OTHER"},"admin_graphql_api_id":"gid:\\/\\/shopify\\/Customer\\/669734 ...

# %%
sql  = "INSERT INTO customers(Ten,DiaChi,SoDienThoai) values (%s, %s, %s)"
val = [("Toàn","VN","1232132121"),
        ("KimToan","Vn","1134213421")]
        
cursor.executemany(sql,val)
conn.commit()

# %%
product = '''create table products(
    Ten varchar(255),
    Gia varchar(255),
    SoLuong varchar(10)
);'''
cursor.execute(product)

# %%
sql  = "INSERT INTO products(Ten,Gia,SoLuong) values (%s, %s, %s)"
val = [("Áo nữ đẹp New","21","20"),
        ("KimToan","21","14")]
        
cursor.executemany(sql,val)
conn.commit()

# %%
response_get_product = requests.get("https://007af9e4efaee0e02d3101cce3eb07b3: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@luxury-4832.myshopify.com/admin/api/2022-10/products.json?limit=100")

# %%
response_get_product.text
# Out:
# '{"products":[{"id":8016471032116,"title":"Áo nữ đẹp New","body_html":"\\u003cp data-mce-fragment=\\"1\\"\\u003eĐặc tính: Nữ tính - Trẻ trung - Năng động.\\u003c\\/p\\u003e\\n\\u003cp data-mce-fragment=\\"1\\"\\u003eThể loại: Trang phục dạo phố.\\u003c\\/p\\u003e\\n\\u003cp data-mce-fragment=\\"1\\"\\u003eSize: S\\/M\\/L.\\u003c\\/p\\u003e\\n\\u003cdiv id=\\"eJOY__extension_root\\" class=\\"eJOY__extension_root_class\\" style=\\"all: unset;\\"\\u003e\\u003c\\/div\\u003e","vendor":"Luxury Shop","product_type":"T-shirt","created_at":"2022-11-22T13:20:16+07:00","handle":"ao-nữ-dẹp-2022","updated_at":"2022-11-22T16:36:46+07:00","published_at":"2022-11-22T13:20:17+07:00","template_suffix":"","status":"active","published_scope":"global","tags":"","admin_graphql_api_id":"gid:\\/\\/shopify\\/Product\\/8016471032116","variants":[{"id":43989451079988,"product_id":8016471032116,"title":"S \\/ Black","price":"15.00","sku":"","position":1,"inventory_policy":"deny","compare_at_price":"20.00","fulfillment_service":"manual","inventory_management":"shopify","option1":"S","option2":"Black","option3":null,"created_at":"2022-11-22T13:20:16+07:00","updated_at":"2022-11-22T16:36:46+07:00","taxable":true,"barcode":"","grams":200,"image_id":null,"weight":0.2,"weight_unit":"kg","inventory_item_id":46038612050228,"inventory_quantity":3,"old_inventory_quantity":3,"requires_shipping":true,"admin_graphql_api_id":"gid:\\/\\/shopify\\/ProductVariant\\/43989451079988"},{"id":43989451112756,"product_id":8016471032116,"title":"S \\/ White","price":"15.00","sku":"","position":2,"inventory_policy":"deny","compare_at_price":"20.00","fulfillment_service":"manual","inventory_management":"shopify","option1":"S","option2":"White","option3":null,"created_at":"2022-11-22T13:20:16+07:00","updated_at":"2022-11-22T16:36:45+07:00","taxable":true,"barcode":"","grams":200,"image_id":null,"weight":0.2,"weight_unit":"kg","inventory_item_id":46038612082996,"inventory_quantity":4,"old_inventory_quantity":4,"requires_shipping":true,"admin_graphql_api_id":"gid:\\/\\/shopify\\/ProductVariant\\/43989451112756"},{"id":43989451145524,"product_id":8016471032116,"title":"S \\/ Pink","price":"15.00","sku":"","position":3,"inventory_policy":"deny","compare_at_price":"20.00","fulfillment_service":"manual","inventory_management":"shopify","option1":"S","option2":"Pink","option3":null,"created_at":"2022-11-22T13:20:16+07:00","updated_at":"2022-11-22T16:36:46+07:00","taxable":true,"barcode":"","grams":200,"image_id":null,"weight":0.2,"weight_unit":"kg","inventory_item_id":46038612115764,"inventory_quantity":5,"old_inventory_quantity":5,"requires_shipping":true,"admin_graphql_api_id":"gid:\\/\\/shopify\\/ProductVariant\\/43989451145524"},{"id":43989451178292,"product_id":8016471032116,"title":"M \\/ Black","price":"15.00","sku":"","position":4,"inventory_policy":"deny","compare_at_price":"20.00","fulfillment_service":"manual","inventory_management":"shopify","option1":"M","option2":"Black","option3":null,"created_at":"2022-11-22T13:20:16+07:00","updated_at":"2022-11-22T16:36:46+07:00","taxable":true,"barcode":"","grams":200,"image_id":null,"weight":0.2,"weight_unit":"kg","inventory_item_id":46038612148532,"inventory_quantity":5,"old_inventory_quantity":5,"requires_shipping":true,"admin_graphql_api_id":"gid:\\/\\/shopify\\/ProductVariant\\/43989451178292"},{"id":43989451211060,"product_id":8016471032116,"title":"M \\/ White","price":"15.00","sku":"","position":5,"inventory_policy":"deny","compare_at_price":"20.00","fulfillment_service":"manual","inventory_management":"shopify","option1":"M","option2":"White","option3":null,"created_at":"2022-11-22T13:20:16+07:00","updated_at":"2022-11-22T16:36:46+07:00","taxable":true,"barcode":"","grams":200,"image_id":null,"weight":0.2,"weight_unit":"kg","inventory_item_id":46038612181300,"inventory_quantity":1,"old_inventory_quantity":1,"requires_shipping":true,"admin_graphql_api_id":"gid:\\/\\/shopify\\/ProductVariant\\/43989451211060"},{"id":43989451243828 ...
